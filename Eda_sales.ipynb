# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_excel('Superstore_USA.xlsx')

# %%
dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
dataset['Product Base Margin']= dataset['Product Base Margin'].fillna(dataset['Product Base Margin'].mean())

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
dataset.shape
# Out:
# (9426, 24)

# %% [markdown]
# # order priority

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
dataset['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
dataset['Order Priority']= dataset['Order Priority'].replace('Critical ','Critical')

# %%
dataset['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical'], dtype=object)

# %%
sns.countplot(x="Order Priority",data=dataset)
plt.title("Count of order Priority")
plt.savefig("Count of order Priority.jpg")
plt.show()

# %%
dataset["Order Priority"].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %% [markdown]
# # ship mode

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x = dataset['Ship Mode'].value_counts().index
y = dataset['Ship Mode'].value_counts().values

# %%
plt.pie(y,labels=x,startangle = 60, autopct="%0.2f%%")
plt.title("Ship mode")
plt.legend(loc=2)
plt.savefig("Ship mode.jpg")
plt.show()

# %%
sns.countplot(x="Ship Mode", data=dataset, hue="Product Category")
plt.title("shipping mode and Product category")
plt.savefig("Ship mode for product category.jpg")
plt.show()

# %% [markdown]
# # customer segment

# %%
sns.countplot(x="Customer Segment", data=dataset)
plt.savefig('Customer Segment.jpg') 
plt.show()

# %% [markdown]
# # Product Category

# %%
sns.countplot(x="Product Category", data=dataset)
plt.savefig('Product Category.jpg') 
plt.show()

# %%
sns.countplot(x="Product Category", data=dataset[dataset["Product Category"]=="Office Supplies"], hue="Product Sub-Category")
plt.savefig('Office supply for product sub category.jpg') 
plt.show()

# %%
dataset["Order Year"] = dataset["Order Date"].dt.year

# %%
dataset["Order Year"].value_counts()
# Out:
# Order Year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
sns.countplot(x="Order Year", data=dataset)
plt.savefig("order year.jpg")
plt.show()

# %%
sns.barplot(x="Product Category" , y="Profit", data=dataset, estimator="sum")
plt.savefig("Product Category profit.jpg") 
plt.show()
